# %%
import pandas as pd
import numpy as np
import math as m

# %%
# Example DataFrame
data = {'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]}
df = pd.DataFrame(data)
df = df.set_index('A')  # Setting column 'A' as the index
df
# Accessing a single value
# value = df.loc[1, 'B']
# print(value)  # Output will be 4
# Out:
#    B  C
# A
# 1  4  7
# 2  5  8
# 3  6  9

# %% [markdown]
# ## Demonstrating the Effects of Right-skewed Log-Transform Normalization
#
# - in a right skewed distribution, smaller powers of a base cover a very small portion of the distribution
# - this results in a tail on the left side of the log-transform distribution
# - increasing powers begin to cover much larger portions of the distribution resulting in 1-2 powers covering the bulk of the original dist and resulting in the familiar bell-shape in the center of the log-transform dist
# - mere fractions of the higher powers now cover the remaining data points in the original dist resulting in the right tail of the log-transform dist

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Generate a right-skewed distribution
salaries = np.random.exponential(scale=50000, size=1000)

# Log-transform the salaries
log_salaries = np.log10(salaries)

# Plot the original and log-transformed distributions
fig, ax = plt.subplots(2, 1, figsize=(50, 6))

sns.histplot(salaries, bins=100, kde=True, ax=ax[0])
ax[0].set_title('Original Salaries')
ticks = np.arange(salaries.min(), salaries.max(), step=10000)
ax[0].set_xticks(ticks)

sns.histplot(log_salaries, bins=50, kde=True, ax=ax[1])
ax[1].set_title('Log-Transformed Salaries')
log_ticks = np.arange(log_salaries.min(), log_salaries.max(), step=0.1)
ax[1].set_xticks(log_ticks)

plt.show()
# Out:
# /home/syarnaq/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/syarnaq/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
